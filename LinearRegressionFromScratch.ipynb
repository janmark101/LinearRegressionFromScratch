# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def Cost_function(x,y,w,b):
    cost_func = 0
    temp = 0
    m = x.shape[0]
    for i in range(m):
        temp += ((w*x[i] + b) - y[i]) **2
    cost_func = 1/(2*m) * temp
    return cost_func

# %%
def Gradient_descent(x,y,w,b,a):
    m = x.shape[0]

    cost_w = 0
    cost_b = 0
    for i in range(m):
        cost_w += ((w*x[i] + b) - y[i]) * x[i]
        cost_b += ((w*x[i] + b) - y[i])
    cost_w = cost_w / m
    cost_b = cost_b /m

    w = w - a * cost_w
    b = b - a * cost_b
    
    return w,b

# %%
data = pd.read_csv('test.csv')
x = np.array(data['x'])
y = np.array(data['y'])

# %%
plt.scatter(data.x,data.y)

# %%
w = 0
b = 0
a = 0.0001
epochs = 20

# %%
for i in range(epochs):
    w , b = Gradient_descent(x,y,w,b,a)
    print(Cost_function(x,y,w,b), f"epochs : {i}")
# Out:
# [772.03938758] epochs : 0
# [326.946151] epochs : 1
# [140.66563368] epochs : 2
# [62.70347138] epochs : 3
# [30.07473037] epochs : 4
# [16.4189426] epochs : 5
# [10.70371931] epochs : 6
# [8.31178278] epochs : 7
# [7.31070894] epochs : 8
# [6.89173925] epochs : 9
# [6.71639191] epochs : 10
# [6.64300546] epochs : 11
# [6.61229169] epochs : 12
# [6.59943731] epochs : 13
# [6.59405744] epochs : 14
# [6.59180581] epochs : 15
# [6.5908634] epochs : 16
# [6.59046894] epochs : 17
# [6.5903038] epochs : 18
# [6.59023463] epochs : 19

# %%
plt.scatter(data.x,data.y,color='black')
plt.plot([w*x + b for x in range(-0,105)],color='red')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = x.reshape(-1,1)
y = y.reshape(-1,1)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
plt.scatter(x,y,color='black')
plt.plot(x_test,y_pred,color='red')
plt.show()

# %%
w_sk = reg.coef_[0]
b_sk = reg.intercept_

print("My linear regression : ")
print("w :", w)
print("b :", b)

print("\nLinear regression with sklearn : ")
print("w :", w_sk)
print("b :", b_sk)
# Out:
# My linear regression :
# w : [1.01757707]
# b : [0.01488891]
#
# Linear regression with sklearn :
# w : [1.01626147]
# b : [0.32524529]
